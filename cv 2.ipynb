# %%
pip install opencv-python
# Out:
# ...
#
# ...

# %%
import cv2

# Load the image
image = cv2.imread(r'C:\Users\admin\Pictures\download.jfif', cv2.IMREAD_GRAYSCALE)

# Find the minimum and maximum pixel values
min_pixel = image.min()
max_pixel = image.max()

print(f'Minimum pixel value: {min_pixel}')
print(f'Maximum pixel value: {max_pixel}')
# Out:
# Minimum pixel value: 0
# Maximum pixel value: 250

# %% [markdown]
# # Assistant
# The error occurs because of the way the file path is specified. In Python, the backslash (`\`) is used as an escape character, which can lead to issues when specifying file paths on Windows.
#
# In your code, the path `'C:\Users\admin\Pictures\download (2).jpg'` contains backslashes that are interpreted as escape sequences, causing the `SyntaxError`.
#
# To fix this, you can either:
# 1. Use double backslashes (`\\`) in the file path.
# 2. Use a raw string by prefixing the string with `r`, which tells Python to treat backslashes as literal characters.
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # Assistant
# The error occurs because of the way the file path is specified. In Python, the backslash (`\`) is used as an escape character, which can lead to issues when specifying file paths on Windows.
#
# In your code, the path `'C:\Users\admin\Pictures\download.jfif'` contains backslashes that are interpreted as escape sequences, causing the `SyntaxError`.
#
# To fix this, you can either:
# 1. Use double backslashes (`\\`) in the file path.
# 2. Use a raw string by prefixing the string with `r`, which tells Python to treat backslashes as literal characters.
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # Assistant
# The error occurs because the `cv2.imread()` function is returning `None`. This typically happens when the image file cannot be found at the specified path, or the path is incorrect.
#
# To fix this error, you should first check if the image was loaded successfully before trying to access its attributes. You can do this by adding a condition to verify that `image` is not `None`.
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # User
# yes

# %%
# Assistant
import cv2

# Load the image
image = cv2.imread(r'C:\Users\admin\Pictures\download.jfif', cv2.IMREAD_GRAYSCALE)

# Check if the image was loaded successfully
if image is not None:
    # Find the minimum and maximum pixel values
    min_pixel = image.min()
    max_pixel = image.max()

    print(f'Minimum pixel value: {min_pixel}')
    print(f'Maximum pixel value: {max_pixel}')
else:
    print("Error: Image not found. Please check the file path.")
# Out:
# Minimum pixel value: 0
# Maximum pixel value: 250

# %% [markdown]
# # Changes made:
# - Added a check to see if `image` is `None` before trying to access its attributes. This prevents the `AttributeError` and provides a user-friendly error message if the image cannot be loaded.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the original image
image = cv2.imread(r'C:\Users\admin\Pictures\download.jfif')

# Function to display images
def show_image(title, img):
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.axis('off')
    plt.show()

# Rotate the image by 90 degrees
rotated = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)
show_image('Rotated Image', rotated)

# Flip the image horizontally
flipped = cv2.flip(image, 1)
show_image('Flipped Image', flipped)

# Crop the image
cropped = image[50:200, 50:200]
show_image('Cropped Image', cropped)

# Resize the image
resized = cv2.resize(image, (100, 100))
show_image('Resized Image', resized)

# Add Gaussian noise
noise = np.random.normal(0, 25, image.shape).astype(np.uint8)
noisy_image = cv2.add(image, noise)
show_image('Noisy Image', noisy_image)

# Change brightness
brightened = cv2.convertScaleAbs(image, alpha=1.2, beta=30)
show_image('Brightened Image', brightened)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
show_image('Grayscale Image', gray)

# Shear transformation
rows, cols, ch = image.shape
pts1 = np.float32([[50,50], [200,50], [50,200]])
pts2 = np.float32([[10,100], [200,50], [100,250]])
M = cv2.getAffineTransform(pts1, pts2)
sheared = cv2.warpAffine(image, M, (cols, rows))
show_image('Sheared Image', sheared)

# %% [markdown]
# # Assistant
# The error occurs because the `cv2.imread()` function is returning `None`. This typically happens when the image file cannot be found at the specified path, or the path is incorrect.
#
# To fix this error, you should first check if the image was loaded successfully before trying to access its attributes. You can do this by adding a condition to verify that `image` is not `None`.
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # User
# yes

# %%
# Assistant
import cv2

# Load the image
image = cv2.imread(r'C:\Users\admin\Pictures\download.jfif', cv2.IMREAD_GRAYSCALE)

# Check if the image was loaded successfully
if image is not None:
    # Find the minimum and maximum pixel values
    min_pixel = image.min()
    max_pixel = image.max()

    print(f'Minimum pixel value: {min_pixel}')
    print(f'Maximum pixel value: {max_pixel}')
else:
    print("Error: Image not found. Please check the file path.")
# Out:
# Minimum pixel value: 0
# Maximum pixel value: 250

# %% [markdown]
# # Changes made:
# - Added a check to see if `image` is `None` before trying to access its attributes. This prevents the `AttributeError` and provides a user-friendly message if the image is not found.

# %% [markdown]
# # Assistant
# The error you're encountering indicates that the OpenCV library (`cv2`) is not installed in your Python environment. This means that when you try to import it, Python cannot find the module.
#
# To fix this error, you need to install the OpenCV library. You can do this using pip.
#
# Would you like me to provide the command to install OpenCV?

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the original image
image = cv2.imread(r'C:\Users\admin\Pictures\download.jfif', cv2.IMREAD_GRAYSCALE)

# Create a CLAHE object
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))

# Apply CLAHE to the image
cl1 = clahe.apply(image)

# Function to plot histogram
def plot_histogram(image, title):
    plt.hist(image.ravel(), bins=256, range=[0, 256], color='black')
    plt.title(title)
    plt.xlabel('Pixel Value')
    plt.ylabel('Frequency')
    plt.show()

# Display the original and CLAHE images
cv2.imshow('Original Image', image)
cv2.imshow('CLAHE Image', cl1)

# Plot histograms
plot_histogram(image, 'Histogram of Original Image')
plot_histogram(cl1, 'Histogram of CLAHE Image')

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cl1
